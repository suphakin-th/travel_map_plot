# %%
import pandas as pd
import folium

# %%
file_path = "tourist_attraction.csv"
df = pd.read_csv(file_path)

# Create a map centered around the first location
m = folium.Map(location=[df['latitude'].iloc[0], df['longitude'].iloc[0]], zoom_start=2.475)

# Add markers for each location
for index, row in df.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"{row['place_name']} - {row['description']}",
        icon=folium.Icon(color='red')
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34c57a0a0ce1fc627dd63b71d9175c79 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34c57a0a0ce1fc627dd63b71d9175c79&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_34c57a0a0ce1fc627dd63b71d9175c79 = L.map(
#                 &quot;map_34c57a0a0ce1fc627dd63b71d9175c79&quot;,
#                 {
#                     center: [35.66, 139.75],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2.475,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf72cb4a15e83051892c071a241f5373 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_34c57a0a0ce1fc627dd63b71d9175c79);
#
#
#             var marker_0e58dba57e500d3b098b492285e4d8df = L.marker(
#                 [35.66, 139.75],
#                 {}
#             ).addTo(map_34c57a0a0ce1fc627dd63b71d9175c79);
#
#
#             var icon_e2d161c6082c93f31f1a01d8e0a5cfdb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0e58dba57e500d3b098b492285e4d8df.setIcon(icon_e2d161c6082c93f31f1a01d8e0a5cfdb);
#
#
#         var popup_570326c543ab123c47d347aaed60b8fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21ddda14bd3051383201efd776a2ef39 = $(`&lt;div id=&quot;html_21ddda14bd3051383201efd776a2ef39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tokyo Tower - Iconic landmark offering panoramic views of Tokyo&lt;/div&gt;`)[0];
#                 popup_570326c543ab123c47d347aaed60b8fa.setContent(html_21ddda14bd3051383201efd776a2ef39);
#
#
#
#         marker_0e58dba57e500d3b098b492285e4d8df.bindPopup(popup_570326c543ab123c47d347aaed60b8fa)
#         ;
#
#
#
#
#             var marker_cd78f5ac0c76a2bdea256f40d7a84a2e = L.marker(
#                 [26.99, 75.85],
#                 {}
#             ).addTo(map_34c57a0a0ce1fc627dd63b71d9175c79);
#
#
#             var icon_a078ac398535951ccd5827a760d06581 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cd78f5ac0c76a2bdea256f40d7a84a2e.setIcon(icon_a078ac398535951ccd5827a760d06581);
#
#
#         var popup_0cd6226cec2ded1ede4df9a8a503a917 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_72f62b49bdb50e7d36133782e8bee11a = $(`&lt;div id=&quot;html_72f62b49bdb50e7d36133782e8bee11a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Amer Fort - Majestic fort with stunning architecture and scenic surroundings&lt;/div&gt;`)[0];
#                 popup_0cd6226cec2ded1ede4df9a8a503a917.setContent(html_72f62b49bdb50e7d36133782e8bee11a);
#
#
#
#         marker_cd78f5ac0c76a2bdea256f40d7a84a2e.bindPopup(popup_0cd6226cec2ded1ede4df9a8a503a917)
#         ;
#
#
#
#
#             var marker_3e2b73cfebe33d93bec7b0ed6ca0ba2f = L.marker(
#                 [40.43, 116.57],
#                 {}
#             ).addTo(map_34c57a0a0ce1fc627dd63b71d9175c79);
#
#
#             var icon_bd2b0e97e0ec807f0c112c501857330b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3e2b73cfebe33d93bec7b0ed6ca0ba2f.setIcon(icon_bd2b0e97e0ec807f0c112c501857330b);
#
#
#         var popup_957755f3595ebab334960610ff7dd80f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cc8e3b27c274acf7a578dbc6845e227d = $(`&lt;div id=&quot;html_cc8e3b27c274acf7a578dbc6845e227d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Great Wall of China - World-famous wall with a rich history and breathtaking views&lt;/div&gt;`)[0];
#                 popup_957755f3595ebab334960610ff7dd80f.setContent(html_cc8e3b27c274acf7a578dbc6845e227d);
#
#
#
#         marker_3e2b73cfebe33d93bec7b0ed6ca0ba2f.bindPopup(popup_957755f3595ebab334960610ff7dd80f)
#         ;
#
#
#
#
#             var marker_977e13d9d6fcddb21663b350da8dab5a = L.marker(
#                 [13.75, 100.49],
#                 {}
#             ).addTo(map_34c57a0a0ce1fc627dd63b71d9175c79);
#
#
#             var icon_6de7c4
